# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os
from config import census_key
import json
import requests 
from census import Census

c = Census(census_key, year=2010)

# %%
# Import Accident dataset

accident_data = pd.read_csv(r'usaccidents.csv')
#accident_data.head()
len(accident_data)

# Remove columns
#del df['column_name']
# Out:
# 2974335

# %%
# Get Holiday List
holiday_data = pd.read_csv(r'holidaylist.csv')
holiday_data
# Out:
#      Unnamed: 0        Date                              Holiday
# 0             0  12/31/2010                       New Year's Day
# 1             1   1/17/2011  Birthday of Martin Luther King, Jr.
# 2             2   2/21/2011                Washington's Birthday
# 3             3   5/30/2011                         Memorial Day
# 4             4    7/4/2011                     Independence Day
# ..          ...         ...                                  ...
# 480         480    9/5/1966                            Labor Day
# 481         481  10/12/1966                         Columbus Day
# 482         482  11/11/1966                         Veterans Day
# 483         483  11/24/1966                     Thanksgiving Day
# 484         484  12/25/1966                        Christmas Day
#
# [485 rows x 3 columns]

# %%
# Census API

# Save config information
#url = "https://api.census.gov/data/2010/dec/sf1?get=P001001,NAME&for=us:1&key="

url = "https://api.census.gov/data/2014/pep/natstprc?get=STNAME,POP&DATE_=7&for=state:*&key="


# Build query URL
query_url = url + census_key

census_response = requests.get(query_url)
census_json = census_response.json()

census_pd = pd.DataFrame(census_json)

census_pd
# Out:
#                            0         1      2      3
# 0                     STNAME       POP  DATE_  state
# 1                    Alabama   4849377      7     01
# 2                     Alaska    736732      7     02
# 3                    Arizona   6731484      7     04
# 4                   Arkansas   2966369      7     05
# 5                 California  38802500      7     06
# 6                   Colorado   5355866      7     08
# 7                Connecticut   3596677      7     09
# 8                   Delaware    935614      7     10
# 9       District of Columbia    658893      7     11
# 10                   Florida  19893297      7     12
# 11                   Georgia  10097343      7     13
# 12                    Hawaii   1419561      7     15
# 13                     Idaho   1634464      7     16
# 14                  Illinois  12880580      7     17
# 15                   Indiana   6596855      7     18
# 16                      Iowa   3107126      7     19
# ...
