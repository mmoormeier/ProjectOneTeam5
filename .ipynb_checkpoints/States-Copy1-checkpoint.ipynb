# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import os
from config import census_key
import json
import requests 
#from census import Census

# %%
# Import Accident dataset

accident_data = pd.read_csv(r'usaccidents.csv')


# Drop unnecessary columns
reduced_accident_df = accident_data[["ID", "Severity", "Start_Time", "Start_Lat", "Start_Lng", "Street", "County", "State", "Zipcode", 
                                     "Weather_Timestamp", "Temperature(F)", "Wind_Chill(F)", "Humidity(%)", "Pressure(in)", 
                                     "Visibility(mi)", "Wind_Direction", "Wind_Speed(mph)", "Precipitation(in)", "Weather_Condition"]]
# create df
df = pd.DataFrame(reduced_accident_df)

# Convert dates(object) to integers
df['Start_Time'] = pd.to_datetime(df['Start_Time'])

df['Start_Time'] = df['Start_Time'].apply(lambda x: x.date())

#add to df
df['Start_Time'] = pd.to_datetime(df['Start_Time'])

# %%
# Limit data to two-year period

start_date = "2017-01-01"
end_date = "2019-12-31"

mask = (df['Start_Time'] > start_date) & (df['Start_Time'] <= end_date)
two_year_df = df.loc[mask]
#two_year_df

# %%
# convert date field to integer and use for join field
new_dates = two_year_df['Start_Time'].apply(lambda x: x.strftime('%Y%m%d')).astype(int)

two_year_df['AccidentJoin'] = new_dates

# rename dataframe
accident_2_df = two_year_df
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
# Get Holiday List
holidays = pd.read_csv(r'holidaylist.csv')

# filter down list to 2 years 
start_date = "2017-01-01"
end_date = "2019-12-31"

holiday_df = pd.DataFrame(holidays)

# convert Date to datetime field
holiday_df['Date'] = pd.to_datetime(holiday_df['Date'])

# filter down dataframe
mask = (holiday_df['Date'] > start_date) & (holiday_df['Date'] <= end_date)
holiday_2_df = holiday_df.loc[mask]

# %%
# convert date field to integer and use for join field
new_dates = holiday_2_df['Date'].apply(lambda x: x.strftime('%Y%m%d')).astype(int)

# add column to df
holiday_2_df['HolidayJoin'] = new_dates
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#  Merge Accident and Holiday dataframes

accident_holiday_df=accident_2_df.merge(holiday_2_df,how='left', left_on='AccidentJoin', right_on='HolidayJoin')

accident_holiday_df.head()
# Out:
#        ID  Severity Start_Time  Start_Lat   Start_Lng                 Street  \
# 0  A-9218         2 2017-01-02  38.234737 -122.664314             Bodega Ave
# 1  A-9219         2 2017-01-02  38.246796 -122.627808        E Washington St
# 2  A-9220         2 2017-01-02  38.192196 -122.543053  Old Lakeville No 2 Rd
# 3  A-9221         3 2017-01-02  37.732292 -122.414909                I-280 S
# 4  A-9222         3 2017-01-02  38.211773 -122.144753                 I-80 E
#
#           County State     Zipcode    Weather_Timestamp  ...  Visibility(mi)  \
# 0         Sonoma    CA  94952-1748  2017-01-02 14:15:00  ...            10.0
# 1         Sonoma    CA       94952  2017-01-02 14:15:00  ...            10.0
# 2         Sonoma    CA       94954  2017-01-02 14:35:00  ...            10.0
# 3  San Francisco    CA       94110  2017-01-02 12:56:00  ...            10.0
# 4         Solano    CA       94534  2017-01-02 14:54:00  ...            10.0
#
#    Wind_Direction  Wind_Speed(mph)  Precipitation(in)  Weather_Condition  \
# 0             NNW              3.5                NaN           Overcast
# 1             NNW              3.5                NaN           Overcast
# 2              NW              3.5                NaN           Overcast
# 3             SSW             15.0                NaN           Overcast
# 4              SW             12.7                NaN      Mostly Cloudy
#
#   AccidentJoin  Unnamed: 0       Date         Holiday  HolidayJoin
# 0     20170102        60.0 2017-01-02  New Year's Day   20170102.0
# 1     20170102        60.0 2017-01-02  New Year's Day   20170102.0
# 2     20170102        60.0 2017-01-02  New Year's Day   20170102.0
# 3     20170102        60.0 2017-01-02  New Year's Day   20170102.0
# 4     20170102        60.0 2017-01-02  New Year's Day   20170102.0
#
# [5 rows x 24 columns]

# %%
# accidents per day
total_accidents_sum = len(accident_holiday_df)

# Number of days in 3 years
day_3yr = (365*3)

# calculate accident/day - all
total_per = (total_accidents_sum/day_3yr)

# sum of holiday accidents
holiday_sum = accident_holiday_df['Holiday'].count()

# Number of Holiday days
day_holi = len(holiday_2_df)

# calculate accident/day - holidays
holiday_per = (holiday_sum/day_holi)

# Sum of NON-holiday accidents
non_holiday_sum = len(accident_holiday_df) - accident_holiday_df['Holiday'].count()

# Number of NON holiday days
day_nonholi = (day_3yr - day_holi)

# calculate accident/day - NON holidays
nonholiday_per = (non_holiday_sum/day_nonholi)

# Print Summary dataframe
per_frame_df = pd.DataFrame({
    "Accidents/Day - All": [total_per],
    "Accidents/Day - Holidays": [holiday_per],
    "Accidents/Day - Non-Holiday": [nonholiday_per]
})

#pd.options.display.float_format = "{:,.0f}".format

per_frame_df
# Out:
#    Accidents/Day - All  Accidents/Day - Holidays  Accidents/Day - Non-Holiday
# 0          2341.243836               1928.833333                  2352.861033

# %%
# Drop records without Holiday data

hol_acc_df = accident_holiday_df[accident_holiday_df['Holiday'].notna()]

# get accident count by holiday over course of entire time
holi_count = hol_acc_df.groupby(["Holiday"]).count()["ID"]

#create df
holi_count_df = pd.DataFrame({"Accidents": holi_count})

#reset index
holi_count_df = holi_count_df.reset_index(drop=False)

#Sort df
holi_count_df = holi_count_df.sort_values("Accidents", ascending=False)


holi_count_df
# Out:
#                                Holiday  Accidents
# 2                         Columbus Day       9892
# 8                         Veterans Day       9688
# 9                Washington's Birthday       7347
# 0  Birthday of Martin Luther King, Jr.       7153
# 4                            Labor Day       5806
# 7                     Thanksgiving Day       4584
# 3                     Independence Day       3911
# 5                         Memorial Day       3864
# 6                       New Year's Day       3008
# 1                        Christmas Day       2612

# %%
# Create bar graph
holi_count.plot(kind="bar", facecolor="red", y="holi_count")

# Give the chart a title, x label, and y label
plt.title("Sum of Accidents per Holiday 2017-2019")
plt.xlabel("Holidays")
plt.ylabel("Number of Accidents")
plt.show

plt.savefig("../ProjectOneTeam5/output/3SumHolidayAccidents.png", bbox_inches = "tight")

# %%
#Line graph of all holiday over time

# get accident count by holiday over course of entire time
holi_count = hol_acc_df.groupby(["Start_Time"]).count()["ID"]

#create df
three_year = pd.DataFrame({"Accidents": holi_count})

#reset index
three_year = three_year.reset_index(drop=False)

#merge df with holidays to get holiday name for x axis
three_year_df=three_year.merge(holiday_2_df,how='left', left_on='Start_Time', right_on='Date')
three_year_df.head()
# Out:
#   Start_Time  Accidents  Unnamed: 0       Date  \
# 0 2017-01-02        851          60 2017-01-02
# 1 2017-01-16       1894          61 2017-01-16
# 2 2017-02-20       1876          62 2017-02-20
# 3 2017-05-29        270          63 2017-05-29
# 4 2017-07-04        969          64 2017-07-04
#
#                                Holiday  HolidayJoin
# 0                       New Year's Day     20170102
# 1  Birthday of Martin Luther King, Jr.     20170116
# 2                Washington's Birthday     20170220
# 3                         Memorial Day     20170529
# 4                     Independence Day     20170704

# %%
#create plot
plt.figure(figsize = (20,10))

plt.plot(three_year_df["Date"],three_year_df["Accidents"])

plt.xticks(three_year_df["Date"], three_year_df["Holiday"], rotation = 90)

# label plot
plt.title("Accidents per Holiday From 2017 to 2019")
plt.xlabel("Holidays")
plt.ylabel("Number of Accidents")
plt.show

# save plot as image
plt.savefig("../ProjectOneTeam5/output/4ThreeYearHolidayAccidents.png", bbox_inches = "tight")

# %%
# State

# %%
# convert state name in census data to 2 letter abbreviation
# dict taken from     https://gist.github.com/rogerallen/1583593

us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}
# create dataframe
state_info = pd.DataFrame.from_dict(us_state_abbrev, orient="index")

# reset index
state_info = state_info.reset_index()

# rename columns
state_info.columns = ['Name', 'Abbrev']

#state_info

# %%
# Census API

# State
url = "https://api.census.gov/data/2010/dec/sf1?get=P001001,NAME&for=state:*&key="

# Build query URL
query_url = url + census_key

census_response = requests.get(query_url)
census_json = census_response.json()
census_state_pd = pd.DataFrame(census_json)

# Drop column labels
census_state_df = census_state_pd.drop([census_state_pd.index[0]])

# drop unwanted column
census_state_df = census_state_df.drop(census_state_df.columns[[2]], axis=1)

# rename columns
census_state_df.columns = ['Pop', 'State']

# rearrange columns
census_state_df = census_state_df[['State', 'Pop']]

#convert population to int
census_state_df['Pop'] = census_state_df['Pop'].astype(int)

#census_state_df

# %%
# get accident count by Date
state_acc = accident_2_df.groupby(["State"]).count()["ID"]

#create df
state_acc_df = pd.DataFrame({"Accidents": state_acc})

#reset index
state_acc_df = state_acc_df.reset_index(drop=False)

#state_acc_df

# %%
#merge state census date with state name

# merge state abbrev to state population df
state_pop = census_state_df.merge(state_info,how='left', left_on='State', right_on='Name')

#state_pop
# merge population and accident dataframes
state_pop_acc = state_pop.merge(state_acc_df,how='left', left_on='Abbrev', right_on='State')

state_pop_sum = state_pop_acc
#state_pop_sum

# %%
#  Merge Accident and state population dataframes
state_pop_acc_df = state_pop.merge(state_acc_df,how='left', left_on='Abbrev', right_on='State')

capita_state_df = state_pop_acc_df

# drop columns
clean_state_df = state_pop_acc_df[["State_x", "Pop", "Accidents"]]

# drop Nan values
clean_state_df.dropna(inplace = True)

# Rename column
clean_state_df = clean_state_df.rename(columns={"State_x":"State"})

clean_state_df.head()
#clean_state_df
# Out:
# C:\Users\Matt\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#         State       Pop  Accidents
# 0     Alabama   4779736    36234.0
# 2     Arizona   6392017    59560.0
# 3    Arkansas   2915918     1723.0
# 4  California  37253956   522713.0
# 5   Louisiana   4533372    51632.0

# %%
# 15 most populated states
#Sort df
clean_state_df = clean_state_df.sort_values("Pop", ascending=False)

state_most = clean_state_df.head(15)
state_most
# Out:
#              State       Pop  Accidents
# 4       California  37253956   522713.0
# 43           Texas  25145561   248293.0
# 32        New York  19378102   117770.0
# 11         Florida  18801310   186712.0
# 15        Illinois  12830632    69311.0
# 38    Pennsylvania  12702379    69184.0
# 35            Ohio  11536504    44532.0
# 22        Michigan   9883640    72058.0
# 12         Georgia   9687653    70376.0
# 33  North Carolina   9535483   136313.0
# 30      New Jersey   8791894    42023.0
# 46        Virginia   8001024    73465.0
# 47      Washington   6724540    52050.0
# 21   Massachusetts   6547629    27817.0
# 16         Indiana   6483802    28417.0

# %%
state_most.set_index("State", inplace=True)

# %%
# Create bar graph most populated states
state_most.plot(kind="bar", facecolor="Blue", y="Accidents")

# Give the chart a title, x label, and y label
plt.title("Accidents Most Populated States 2017-2019")
plt.xlabel("States")
plt.ylabel("Number of Accidents")
plt.show

plt.savefig("../ProjectOneTeam5/output/6MostPopulatedStatesGraph.png", bbox_inches = "tight")

# %%
# 15 most populated states
#Sort df
clean_state_df = clean_state_df.sort_values("Pop", ascending=True)

state_least = clean_state_df.head(15)
state_least
# Out:
#                    State      Pop  Accidents
# 50               Wyoming   563626      423.0
# 10  District of Columbia   601723     3199.0
# 45               Vermont   625741      568.0
# 34          North Dakota   672591       40.0
# 41          South Dakota   814180       52.0
# 9               Delaware   897934     4155.0
# 26               Montana   989415      442.0
# 39          Rhode Island  1052567     9080.0
# 29         New Hampshire  1316470     6747.0
# 19                 Maine  1328361     1930.0
# 14                 Idaho  1567582     1338.0
# 27              Nebraska  1826341    16695.0
# 48         West Virginia  1852994     1845.0
# 31            New Mexico  2059179     4867.0
# 28                Nevada  2700551     8167.0

# %%
# Set state as index
state_least.set_index("State", inplace=True)

# %%
# Create bar graph least populated states


state_least.plot(kind="bar", facecolor="orange", y="Accidents")

# Give the chart a title, x label, and y label
plt.title("Accidents Least Populated States 2017-2019")
plt.xlabel("States")
plt.ylabel("Number of Accidents")
plt.show

plt.savefig("../ProjectOneTeam5/output/8LeastPopulatedStatesGraph.png", bbox_inches = "tight")

# %%
#Insight 5

# drop Nan values
capita_state_df.dropna(inplace = True)

#convert float to int
#capita_state_df["Accidents"] = capita_state_df["Accidents"].astype(int)


# Calculate accidents per capita
acc_capita = capita_state_df["Accidents"] / capita_state_df["Pop"]

capita_state_df["Accidents Per 10,000"] = acc_capita * 10000

capita_state_df = capita_state_df.sort_values("Accidents Per 10,000", ascending=False)

capita_state_df.head(20)
# Out:
#            State_x       Pop            Name Abbrev State_y  Accidents  \
# 40  South Carolina   4625364  South Carolina     SC      SC   143674.0
# 37          Oregon   3831074          Oregon     OR      OR    69814.0
# 44            Utah   2763885            Utah     UT      UT    40417.0
# 33  North Carolina   9535483  North Carolina     NC      NC   136313.0
# 4       California  37253956      California     CA      CA   522713.0
# 36        Oklahoma   3751351        Oklahoma     OK      OK    50727.0
# 5        Louisiana   4533372       Louisiana     LA      LA    51632.0
# 23       Minnesota   5303925       Minnesota     MN      MN    60160.0
# 11         Florida  18801310         Florida     FL      FL   186712.0
# 43           Texas  25145561           Texas     TX      TX   248293.0
# 2          Arizona   6392017         Arizona     AZ      AZ    59560.0
# 46        Virginia   8001024        Virginia     VA      VA    73465.0
# 27        Nebraska   1826341        Nebraska     NE      NE    16695.0
# 42       Tennessee   6346105       Tennessee     TN      TN    56601.0
# 39    Rhode Island   1052567    Rhode Island     RI      RI     9080.0
# 47      Washington   6724540      Washington     WA      WA    52050.0
# 7         Colorado   5029196        Colorado     CO      CO    38800.0
# 0          Alabama   4779736         Alabama     AL      AL    36234.0
# 22        Michigan   9883640        Michigan     MI      MI    72058.0
# 12         Georgia   9687653         Georgia     GA      GA    70376.0
#
#     Accidents Per 10,000
# 40            310.622040
# 37            182.230884
# 44            146.232568
# 33            142.953430
# 4             140.310736
# 36            135.223284
# 5             113.893146
# 23            113.425435
# 11             99.307974
# 43             98.742279
# 2              93.178726
# 46             91.819497
# 27             91.412283
# 42             89.190141
# 39             86.265292
# 47             77.403064
# 7              77.149509
# 0              75.807534
# 22             72.906338
# 12             72.645046
